# %%
import pandas as pd
import numpy

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Data = open('Muertes_Etario_T.csv')
datos = pd.read_csv(Data, header=0)

# %%
List=[]
datos = datos.values
Date=[]
Deaths=[]
Date_2=[]
Deaths_2=[]
n=0
Cases_Week=0

for row in datos:
    n=n+1
    i=row[0]
    j=int(row[1])+int(row[2])+int(row[3])+int(row[4])+int(row[5])+int(row[6])+int(row[7])
    Cases_Week=Cases_Week+j
    Date.append(i)
    Deaths.append(j)
   
    if n/7==1:
        Date_2.append(i)
        Deaths_2.append(Cases_Week)
        n=0
        Cases_Week=0


        print(Date_2,Deaths_2)


fig, ax = plt.subplots()

ax.plot(Date_2,Deaths_2, linestyle = "dashed")
plt.show()
# Out:
# ['2020-04-15'] [543]
# ['2020-04-15', '2020-04-22'] [543, 926]
# ['2020-04-15', '2020-04-22', '2020-04-29'] [543, 926, 1333]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06'] [543, 926, 1333, 1795]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06', '2020-05-13'] [543, 926, 1333, 1795, 2199]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06', '2020-05-13', '2020-05-20'] [543, 926, 1333, 1795, 2199, 3164]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06', '2020-05-13', '2020-05-20', '2020-05-27'] [543, 926, 1333, 1795, 2199, 3164, 5018]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06', '2020-05-13', '2020-05-20', '2020-05-27', '2020-06-03'] [543, 926, 1333, 1795, 2199, 3164, 5018, 7461]
# ['2020-04-15', '2020-04-22', '2020-04-29', '2020-05-06', '2020-05-13', '2020-05-20', '2020-05-27', '2020-06-03', '2020-06-10'] [543, 926, 1333, 1795, 2199, 3164, 5018, 7461, 13557]
# ...

# %%
Data = open('Muertes_Respiratorio.csv')
Muertes_Respiratorio = (["Influenza y neumonía"])]
# Out:
#   File "<ipython-input-3-ad9f6d554500>", line 1
#     Defunciones_Totales_Gripe = Defunciones_Totales[Defunciones_Totales.GLOSA_GRUPO_DIAG1.isin(["Influenza
#                                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
Total_Week_Cases = []
Week_Cases_Gripe = []
Week_Cases_Covid = []

# %%
for i in Defunciones_Totales['Week']:
 Total_Week_Cases.append(i);
 
for j in Defunciones_Totales_Gripe['Week']:
 Week_Cases_Gripe.append(j);
 
for k in Defunciones_Totales_COVID['Week']:
 Week_Cases_Covid.append(k);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0bfdcc371466> in <module>()
# ----> 1 for i in Defunciones_Totales['Week']:
#       2  Total_Week_Cases.append(i);
#       3
#       4 for j in Defunciones_Totales_Gripe['Week']:
#       5  Week_Cases_Gripe.append(j);
#
# NameError: name 'Defunciones_Totales' is not defined

# %%
Periodo_Total_Week_Case = range(min(Total_Week_Case),
max(Total_Week_Case) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-afb6c0118449> in <module>()
# ----> 1 Periodo_Total_Week_Case = range(min(Total_Week_Case),
#       2 max(Total_Week_Case) )
#
# NameError: name 'Total_Week_Case' is not defined

# %%
Periodo_Cases_Gripe = range(min(Week_Cases_Gripe),
max(Week_Cases_Gripe))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b30f592c904c> in <module>()
# ----> 1 Periodo_Cases_Gripe = range(min(Week_Cases_Gripe),
#       2 max(Week_Cases_Gripe))
#
# ValueError: min() arg is an empty sequence

# %%
plt.hist(x = Total_Week_Cases, bins =
plt.title('Deaths Total Cases')
plt.xlabel('Week')
plt.ylabel('Muertes')
plt.xticks(Periodo_Total_Week_Case)
plt.show()
# Out:
#   File "<ipython-input-8-de35dab876dc>", line 3
#     plt.xlabel('Week')
#       ^
# SyntaxError: invalid syntax
